# %%
# Imports
import pydicom
import nibabel as nb

# %%
img = nb.load("/autofs/space/simba_001/users/PBR28_KOALA/data/PET/PBRKOA_HC019_01/MR_PET/pCT.nii").get_fdata()
img.shape
# Out:
# (192, 120, 128)

# %%
# !ls /autofs/space/simba_001/users/PBR28_KOALA/data/PET/PBRKOA_HC019_01/pseudo_muMAP
# !cp -rf "/autofs/space/simba_001/users/PBR28_KOALA/data/PET/PBRKOA_HC019_01/pseudo_muMAP" "/autofs/space/celer_001/users/leila"
# Out:
# 581000-000008-000001.dcm  581000-000008-000044.dcm  581000-000008-000087.dcm
# 581000-000008-000002.dcm  581000-000008-000045.dcm  581000-000008-000088.dcm
# 581000-000008-000003.dcm  581000-000008-000046.dcm  581000-000008-000089.dcm
# 581000-000008-000004.dcm  581000-000008-000047.dcm  581000-000008-000090.dcm
# 581000-000008-000005.dcm  581000-000008-000048.dcm  581000-000008-000091.dcm
# 581000-000008-000006.dcm  581000-000008-000049.dcm  581000-000008-000092.dcm
# 581000-000008-000007.dcm  581000-000008-000050.dcm  581000-000008-000093.dcm
# 581000-000008-000008.dcm  581000-000008-000051.dcm  581000-000008-000094.dcm
# 581000-000008-000009.dcm  581000-000008-000052.dcm  581000-000008-000095.dcm
# 581000-000008-000010.dcm  581000-000008-000053.dcm  581000-000008-000096.dcm
# 581000-000008-000011.dcm  581000-000008-000054.dcm  581000-000008-000097.dcm
# 581000-000008-000012.dcm  581000-000008-000055.dcm  581000-000008-000098.dcm
# ...

# %%
# !ls "/autofs/space/celer_001/users/leila"
# Out:
# pbr28  pseudo_muMAP  VBox  working_pbr28
