# %%
# Imports
import glob
import pickle
from tqdm.notebook import tqdm
import os
import subprocess
import nibabel as nb
import numpy as np
import matplotlib.pyplot as plt

# %%
# Paths
USER = "leila" #change the user 
TRACER ="pbr28"
DATA_ROOT = "/autofs/space/simba_001/users/PBR28_KOALA/data/PET"
WORKING_PROCESSED_DATA_PATH = f"/autofs/space/celer_001/users/{USER}/working_pbr28"
WINDOWS_SHARED_DATA_PATH =  f"/autofs/space/celer_001/users/{USER}/pbr28"

# %%
sample_path = "/autofs/space/simba_001/users/PBR28_KOALA/data/PET/PBRKOA_HC019_01/MR_PET/MEMPRAGE_BC_denoised.nii"
img = nb.load(sample_path).get_fdata()

# %%
img = plt
plt.imshow(img[:,:,32])
